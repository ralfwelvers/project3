# %%
# Dependencies
import json
import requests
from pprint import pprint
#from config import api_key
#api_key = '50a4b6e744a360715ece0a489e680b8b'

# %%
# Save config information
url = "https://api.open-meteo.com/v1/forecast?latitude=32.7831&longitude=-96.8067&hourly=temperature_2m,apparent_temperature,precipitation_probability,precipitation&daily=temperature_2m_max,temperature_2m_min&timezone=GMT"

# %%
# URL
chi_url = 'https://api.open-meteo.com/v1/forecast?latitude=41.85&longitude=-87.65&hourly=temperature_2m&temperature_unit=fahrenheit&windspeed_unit=mph&precipitation_unit=inch&timezone=America%2FChicago&start_date=2023-08-20&end_date=2023-08-27'
# Get weather data
response = requests.get(chi_url).json()

# Show Data
pprint(response)
# Out:
# {'elevation': 179.0,
#  'generationtime_ms': 0.18393993377685547,
#  'hourly': {'temperature_2m': [71.0,
#                                71.2,
#                                72.2,
#                                71.5,
#                                70.5,
#                                70.3,
#                                70.0,
#                                70.6,
#                                73.6,
#                                77.4,
#                                81.0,
#                                82.3,
#                                83.0,
#                                84.7,
#                                82.0,
#                                82.6,
#                                81.8,
#                                82.1,
#                                80.6,
#                                78.3,
#                                74.6,
#                                72.0,
#                                71.8,
# ...

# %%
# Url
denton_url = 'https://api.open-meteo.com/v1/forecast?latitude=33.2148&longitude=-97.1331&hourly=temperature_2m&temperature_unit=fahrenheit&windspeed_unit=mph&precipitation_unit=inch&timezone=America%2FChicago&start_date=2023-08-20&end_date=2023-08-27'

# Get weather data
response2 = requests.get(denton_url).json()

# Show Data
pprint(response2)
# Out:
# {'elevation': 203.0,
#  'generationtime_ms': 0.19800662994384766,
#  'hourly': {'temperature_2m': [90.6,
#                                89.0,
#                                88.9,
#                                86.5,
#                                83.8,
#                                83.6,
#                                82.9,
#                                82.7,
#                                84.8,
#                                90.4,
#                                97.4,
#                                101.4,
#                                104.2,
#                                107.0,
#                                109.1,
#                                109.4,
#                                110.0,
#                                109.6,
#                                107.5,
#                                106.9,
#                                103.2,
#                                100.7,
#                                97.4,
# ...

# %%
# Url
sa_url = 'https://api.open-meteo.com/v1/forecast?latitude=29.4241&longitude=-98.4936&hourly=temperature_2m&temperature_unit=fahrenheit&windspeed_unit=mph&precipitation_unit=inch&timezone=America%2FChicago&start_date=2023-08-20&end_date=2023-08-27'

# Get weather data
response3 = requests.get(sa_url).json()

# Show Data
pprint(response2)
# Out:
# {'elevation': 203.0,
#  'generationtime_ms': 0.19800662994384766,
#  'hourly': {'temperature_2m': [90.6,
#                                89.0,
#                                88.9,
#                                86.5,
#                                83.8,
#                                83.6,
#                                82.9,
#                                82.7,
#                                84.8,
#                                90.4,
#                                97.4,
#                                101.4,
#                                104.2,
#                                107.0,
#                                109.1,
#                                109.4,
#                                110.0,
#                                109.6,
#                                107.5,
#                                106.9,
#                                103.2,
#                                100.7,
#                                97.4,
# ...
